# %%
pip install ggplot
# Out:
# Requirement already satisfied: ggplot in c:\users\shantanu jha\anaconda3\lib\site-packages (0.11.5)
# Requirement already satisfied: brewer2mpl in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (1.4.1)
# Requirement already satisfied: cycler in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (0.11.0)
# Requirement already satisfied: matplotlib in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (3.7.2)
# Requirement already satisfied: numpy in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (1.25.1)
# Requirement already satisfied: pandas in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (2.0.3)
# Requirement already satisfied: patsy>=0.4 in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (0.5.2)
# Requirement already satisfied: scipy in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (1.11.1)
# Requirement already satisfied: six in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (1.16.0)
# Requirement already satisfied: statsmodels in c:\users\shantanu jha\anaconda3\lib\site-packages (from ggplot) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (9.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib->ggplot) (6.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas->ggplot) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas->ggplot) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->ggplot) (3.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('F:\\intern\\Recruitment_Data.csv')

# %%
df
# Out:
#      attrition  performance_rating  sales_quota_pct recruiting_source
# 0            1                   3         1.088190    Applied Online
# 1            0                   3         2.394173               NaN
# 2            1                   2         0.497530            Campus
# 3            0                   2         2.513958               NaN
# 4            0                   3         1.424789    Applied Online
# ..         ...                 ...              ...               ...
# 441          0                   3         1.627813            Campus
# 442          1                   4         0.689682          Referral
# 443          0                   4         1.196198               NaN
# 444          0                   4         1.598213    Applied Online
# 445          0                   2         0.582642               NaN
#
# [446 rows x 4 columns]

# %%
# !pip install pandas plotnine
# Out:
# Requirement already satisfied: pandas in c:\users\shantanu jha\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: plotnine in c:\users\shantanu jha\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\shantanu jha\anaconda3\lib\site-packages (from pandas) (1.25.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from plotnine) (3.7.2)
# Requirement already satisfied: mizani>=0.9.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from plotnine) (0.9.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from plotnine) (1.11.1)
# Requirement already satisfied: statsmodels>=0.14.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from plotnine) (0.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (9.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (3.0.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (6.0.0)
# Requirement already satisfied: six in c:\users\shantanu jha\anaconda3\lib\site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shantanu jha\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->plotnine) (3.7.0)

# %%
from plotnine import *

# %%
ggplot(df, aes(x='recruiting_source', y='attrition')) + \
    geom_bar(stat='identity', fill='grey') + \
    ggtitle('Attrition Numbers by Recruiting Source') + \
    xlab('recruiting_source') + ylab('attrition')
# Out:
# <Figure Size: (640 x 480)>

# %%
# The resulting bar chart would show the number of employees who left the company for each recruiting source, 
# making it clear which sources have higher attrition rates. 
# This information can help stakeholders make decisions about which recruiting sources to focus on or adjust their recruiting strategies to reduce attrition. Additionally, the chart title,
# x-axis label, and y-axis label provide context for the data being presented and help justify the decision to use this visua
